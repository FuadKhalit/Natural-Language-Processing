# %% [markdown]
# <a href="https://colab.research.google.com/github/FuadKhalit/Natural-Language-Processing/blob/master/LSTM_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.2.0

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYO6N80/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYO6N80/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYO6N80/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 3000
embedding_dim = 16
max_length = 128
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and <OOV> on the <OOV> and having just <OOV> a lot however on this <OOV> i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was <OOV> them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real <OOV> for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 128, 16)           48000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                9600
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 57,997
# Trainable params: 57,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.5157 - accuracy: 0.7246 - val_loss: 0.4011 - val_accuracy: 0.8237
# Epoch 2/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.3564 - accuracy: 0.8476 - val_loss: 0.3558 - val_accuracy: 0.8476
# Epoch 3/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.3149 - accuracy: 0.8666 - val_loss: 0.3435 - val_accuracy: 0.8492
# Epoch 4/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.2886 - accuracy: 0.8798 - val_loss: 0.3423 - val_accuracy: 0.8515
# Epoch 5/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.2611 - accuracy: 0.8945 - val_loss: 0.3704 - val_accuracy: 0.8493
# Epoch 6/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.2327 - accuracy: 0.9082 - val_loss: 0.3765 - val_accuracy: 0.8431
# Epoch 7/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.2082 - accuracy: 0.9178 - val_loss: 0.4186 - val_accuracy: 0.8413
# Epoch 8/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.1797 - accuracy: 0.9316 - val_loss: 0.4470 - val_accuracy: 0.8387
# Epoch 9/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.1599 - accuracy: 0.9430 - val_loss: 0.4733 - val_accuracy: 0.8033
# Epoch 10/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.1427 - accuracy: 0.9494 - val_loss: 0.5355 - val_accuracy: 0.8064
# Epoch 11/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.1252 - accuracy: 0.9570 - val_loss: 0.5938 - val_accuracy: 0.8264
# Epoch 12/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.1112 - accuracy: 0.9629 - val_loss: 0.6885 - val_accuracy: 0.8222
# Epoch 13/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.0978 - accuracy: 0.9670 - val_loss: 0.6387 - val_accuracy: 0.8151
# Epoch 14/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.0874 - accuracy: 0.9720 - val_loss: 0.6875 - val_accuracy: 0.8114
# Epoch 15/50
# 782/782 [==============================] - 49s 62ms/step - loss: 0.0775 - accuracy: 0.9749 - val_loss: 0.7971 - val_accuracy: 0.8193
# Epoch 16/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0690 - accuracy: 0.9788 - val_loss: 0.8103 - val_accuracy: 0.8160
# Epoch 17/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0582 - accuracy: 0.9838 - val_loss: 0.8996 - val_accuracy: 0.8036
# Epoch 18/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0584 - accuracy: 0.9817 - val_loss: 0.8896 - val_accuracy: 0.8133
# Epoch 19/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0531 - accuracy: 0.9834 - val_loss: 0.9106 - val_accuracy: 0.8094
# Epoch 20/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0439 - accuracy: 0.9874 - val_loss: 1.0018 - val_accuracy: 0.8064
# Epoch 21/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0410 - accuracy: 0.9876 - val_loss: 1.0376 - val_accuracy: 0.8032
# Epoch 22/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 1.2067 - val_accuracy: 0.8077
# Epoch 23/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0330 - accuracy: 0.9904 - val_loss: 1.1355 - val_accuracy: 0.8041
# Epoch 24/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 1.2199 - val_accuracy: 0.8090
# Epoch 25/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 1.2660 - val_accuracy: 0.8159
# Epoch 26/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0254 - accuracy: 0.9919 - val_loss: 1.2306 - val_accuracy: 0.8093
# Epoch 27/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0264 - accuracy: 0.9918 - val_loss: 1.2532 - val_accuracy: 0.8166
# Epoch 28/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 1.3348 - val_accuracy: 0.8102
# Epoch 29/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 1.3318 - val_accuracy: 0.8046
# Epoch 30/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 1.3789 - val_accuracy: 0.8068
# Epoch 31/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 1.3536 - val_accuracy: 0.8111
# Epoch 32/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 1.4421 - val_accuracy: 0.8044
# Epoch 33/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 1.3659 - val_accuracy: 0.8062
# Epoch 34/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 1.2583 - val_accuracy: 0.8040
# Epoch 35/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 1.3816 - val_accuracy: 0.8142
# Epoch 36/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 1.5167 - val_accuracy: 0.8070
# Epoch 37/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 1.4963 - val_accuracy: 0.8009
# Epoch 38/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 1.4720 - val_accuracy: 0.8103
# Epoch 39/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 1.4831 - val_accuracy: 0.8068
# Epoch 40/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 1.5718 - val_accuracy: 0.7998
# Epoch 41/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 1.5073 - val_accuracy: 0.8010
# Epoch 42/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 1.5650 - val_accuracy: 0.8105
# Epoch 43/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 1.6703 - val_accuracy: 0.8072
# Epoch 44/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 1.5364 - val_accuracy: 0.8042
# Epoch 45/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 1.5313 - val_accuracy: 0.8122
# Epoch 46/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 1.5408 - val_accuracy: 0.8093
# Epoch 47/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 1.6387 - val_accuracy: 0.8170
# Epoch 48/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 1.6162 - val_accuracy: 0.8081
# Epoch 49/50
# 782/782 [==============================] - 48s 61ms/step - loss: 0.0156 - accuracy: 0.9944 - val_loss: 1.4662 - val_accuracy: 0.8103
# Epoch 50/50
# 782/782 [==============================] - 48s 62ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 1.5948 - val_accuracy: 0.8059

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 128, 16)           48000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 60,941
# Trainable params: 60,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Definition with Conv1D
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 128, 16)           48000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 124, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 59,149
# Trainable params: 59,149
# Non-trainable params: 0
# _________________________________________________________________
